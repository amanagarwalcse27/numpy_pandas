# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\AMAN\OneDrive\Desktop\python ml\pandas\ipl-matches.csv")

# %%
df
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
df.head() #df.head(n)will show n rows starting from start
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
df.shape #gives rows and columns
# Out:
# (950, 20)

# %%
print(df['City']) #gives 1 column in form of SERIES
print()
type(df['City'])
# Out:
# 0       Ahmedabad
# 1       Ahmedabad
# 2         Kolkata
# 3         Kolkata
# 4          Mumbai
#           ...
# 945       Kolkata
# 946        Mumbai
# 947         Delhi
# 948    Chandigarh
# 949     Bangalore
# Name: City, Length: 950, dtype: object
# pandas.core.series.Series

# %%
df[['City','Date']] #to get required columns pass in form of list
# Out:
#            City        Date
# 0     Ahmedabad  2022-05-29
# 1     Ahmedabad  2022-05-27
# 2       Kolkata  2022-05-25
# 3       Kolkata  2022-05-24
# 4        Mumbai  2022-05-22
# ..          ...         ...
# 945     Kolkata  2008-04-20
# 946      Mumbai  2008-04-20
# 947       Delhi  2008-04-19
# 948  Chandigarh  2008-04-19
# 949   Bangalore  2008-04-18
#
# [950 rows x 2 columns]

# %%
SLICING AND INDEXING USING iloc and loc

# %%
#for rows 
df.loc[0:3]  # inclusive(include krega) of 0 and 3
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# 3             Eden Gardens, Kolkata        Gujarat Titans        field
#
# ...

# %%
 #iloc in exclusive of last endpoint
#for rows
df.iloc[0:4] #0 and 3 tk krega
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# 3             Eden Gardens, Kolkata        Gujarat Titans        field
#
# ...

# %%
#for columns 
 # slicing of list me ,(comma) ke phle rows ka and  comma ke baad columns ka likhna h  hoga 
df.iloc[:,0:4] #saare rows included ,column from index 0 to 4-1 =3 tk
# Out:
#           ID        City        Date   Season
# 0    1312200   Ahmedabad  2022-05-29     2022
# 1    1312199   Ahmedabad  2022-05-27     2022
# 2    1312198     Kolkata  2022-05-25     2022
# 3    1312197     Kolkata  2022-05-24     2022
# 4    1304116      Mumbai  2022-05-22     2022
# ..       ...         ...         ...      ...
# 945   335986     Kolkata  2008-04-20  2007/08
# 946   335985      Mumbai  2008-04-20  2007/08
# 947   335984       Delhi  2008-04-19  2007/08
# 948   335983  Chandigarh  2008-04-19  2007/08
# 949   335982   Bangalore  2008-04-18  2007/08
#
# [950 rows x 4 columns]

# %%
#in reverse direction
df.iloc[-1:-5:-1,:]
# Out:
#          ID        City        Date   Season MatchNumber  \
# 949  335982   Bangalore  2008-04-18  2007/08           1
# 948  335983  Chandigarh  2008-04-19  2007/08           2
# 947  335984       Delhi  2008-04-19  2007/08           3
# 946  335985      Mumbai  2008-04-20  2007/08           5
#
#                            Team1                        Team2  \
# 949  Royal Challengers Bangalore        Kolkata Knight Riders
# 948              Kings XI Punjab          Chennai Super Kings
# 947             Delhi Daredevils             Rajasthan Royals
# 946               Mumbai Indians  Royal Challengers Bangalore
#
#                                           Venue                   TossWinner  \
# 949                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 948  Punjab Cricket Association Stadium, Mohali          Chennai Super Kings
# 947                            Feroz Shah Kotla             Rajasthan Royals
# ...

# %%
APPLYING FUNCTIONS AND ATTRIBUTES ON PARTICULAR function

# %%
VALUE COUNT function
#1.   apply on series datatype i.e on only one column
#2.  apply it on categorical data 
#3.  gives total values or frequency  for each category

# %%
df['City'].value_counts().head(3) #only 3 rows
# Out:
# City
# Mumbai     159
# Kolkata     79
# Delhi       78
# Name: count, dtype: int64

# %%
df1 = df['Team1'].value_counts() + df['Team2'].value_counts() 
df1
# Out:
# Chennai Super Kings            208
# Deccan Chargers                 75
# Delhi Capitals                  63
# Delhi Daredevils               161
# Gujarat Lions                   30
# Gujarat Titans                  16
# Kings XI Punjab                190
# Kochi Tuskers Kerala            14
# Kolkata Knight Riders          223
# Lucknow Super Giants            15
# Mumbai Indians                 231
# Pune Warriors                   46
# Punjab Kings                    28
# Rajasthan Royals               192
# Rising Pune Supergiant          16
# Rising Pune Supergiants         14
# Royal Challengers Bangalore    226
# Sunrisers Hyderabad            152
# Name: count, dtype: int64

# %%
#SORT FUNCTION

#WORKS ON SERIES AS WELL AS DATAFRAME DATATYPE

# %%
df1.sort_values(ascending=False).head() #FOR DESCENDING order make ascending false
# Out:
# Mumbai Indians                 231
# Royal Challengers Bangalore    226
# Kolkata Knight Riders          223
# Chennai Super Kings            208
# Rajasthan Royals               192
# Name: count, dtype: int64

# %%
df.sort_values('City').head(3)
# Out:
#           ID       City        Date   Season  MatchNumber  \
# 135  1237180  Abu Dhabi  2020-11-08  2020/21  Qualifier 2
# 95   1254098  Abu Dhabi  2021-09-26     2021           38
# 533   729315  Abu Dhabi  2014-04-29     2014           19
#
#                      Team1                Team2  \
# 135         Delhi Capitals  Sunrisers Hyderabad
# 95   Kolkata Knight Riders  Chennai Super Kings
# 533  Kolkata Knight Riders     Rajasthan Royals
#
#                                 Venue             TossWinner TossDecision  \
# 135              Sheikh Zayed Stadium         Delhi Capitals          bat
# 95   Zayed Cricket Stadium, Abu Dhabi  Kolkata Knight Riders          bat
# 533              Sheikh Zayed Stadium       Rajasthan Royals          bat
#
#     SuperOver          WinningTeam      WonBy  Margin method Player_of_Match  \
# 135         N       Delhi Capitals       Runs    17.0    NaN      MP Stoinis
# 95          N  Chennai Super Kings    Wickets     2.0    NaN       RA Jadeja
# ...

# %%
df.sort_values(['City','Date']).head(2)
# Out:
#          ID       City        Date Season MatchNumber                Team1  \
# 551  729279  Abu Dhabi  2014-04-16   2014           1       Mumbai Indians
# 548  729285  Abu Dhabi  2014-04-18   2014           4  Sunrisers Hyderabad
#
#                      Team2                 Venue             TossWinner  \
# 551  Kolkata Knight Riders  Sheikh Zayed Stadium  Kolkata Knight Riders
# 548       Rajasthan Royals  Sheikh Zayed Stadium       Rajasthan Royals
#
#     TossDecision SuperOver            WinningTeam    WonBy  Margin method  \
# 551          bat         N  Kolkata Knight Riders     Runs    41.0    NaN
# 548        field         N       Rajasthan Royals  Wickets     4.0    NaN
#
#     Player_of_Match                                       Team1Players  \
# 551       JH Kallis  ['MEK Hussey', 'AP Tare', 'AT Rayudu', 'RG Sha...
# 548       AM Rahane  ['AJ Finch', 'S Dhawan', 'DA Warner', 'KL Rahu...
#
#                                           Team2Players    Umpire1  \
# ...

# %%
#drop duplicates function
#removes duplicates rows 
#check row by row

# %%
df.drop_duplicates(subset=['City','Season']).head()
# Out:
#          ID         City        Date Season MatchNumber  \
# 0   1312200    Ahmedabad  2022-05-29   2022       Final
# 2   1312198      Kolkata  2022-05-25   2022  Eliminator
# 4   1304116       Mumbai  2022-05-22   2022          70
# 8   1304112  Navi Mumbai  2022-05-18   2022          66
# 13  1304107         Pune  2022-05-14   2022          61
#
#                           Team1                  Team2  \
# 0              Rajasthan Royals         Gujarat Titans
# 2   Royal Challengers Bangalore   Lucknow Super Giants
# 4           Sunrisers Hyderabad           Punjab Kings
# 8          Lucknow Super Giants  Kolkata Knight Riders
# 13        Kolkata Knight Riders    Sunrisers Hyderabad
#
#                                             Venue             TossWinner  \
# 0                Narendra Modi Stadium, Ahmedabad       Rajasthan Royals
# 2                           Eden Gardens, Kolkata   Lucknow Super Giants
# ...

# %%
# FILTERING OF DATA

#phle given column find kro then apply condition on it and then store it in variable called mask generally

# %%
#finding matches of hyderabad

# %%
mask = df['City']== 'Hyderabad'
print(df[mask])
print()
df[mask].shape #gives total rows

# %%
#CREATE FUNCTION TO FIND MATCHES IN CITY TAKEN INPUT FROM USER

# %%
def get_city_match_count(city):
    mask = df['City'] == city
    return df[mask].shape

# %%
get_city_match_count('Rajkot')
# Out:
# (10, 20)

# %%
#find matches in ahmedabad after jan1 2010

# %%
mask1 = df['City']=='Ahemadabad' #gives matches in Ahemadabad
df[mask1].head()
print()
mask2 = df['Date']> '2010-01-01'  #gives matches after JAN1,2010
df[ mask2].head()

df[mask1 & mask2] #gives matches in ahemdabad after jan1,2010
